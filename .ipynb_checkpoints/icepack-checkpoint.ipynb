# %%
# %matplotlib notebook 
import matplotlib.pyplot as plt
import firedrake
import icepack, icepack.plot, icepack.models
import numpy as np

# %%
Lx, Ly = 20e3, 20e3
nx, ny = 16, 16
mesh = firedrake.RectangleMesh(nx,ny,Lx,Ly)

# %%
fig, axes = icepack.plot.subplots()
icepack.plot.triplot(mesh,axes=axes)
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">

# %%
Q = firedrake.FunctionSpace(mesh,family='CG',degree=2)
V = firedrake.VectorFunctionSpace(mesh,family='CG',degree=2)

# %%
print(V)
# Out:
# WithGeometry(FunctionSpace(<firedrake.mesh.MeshTopology object at 0x1264d79b0>, <vector element with 2 components of <CG2 on a triangle>>, name=None), <Mesh #1>)

# %%
x, y = firedrake.SpatialCoordinate(mesh)
# meters
h0, δh = 500.0, 100.0
h = firedrake.interpolate(h0- δh * x /Lx,Q)
#initial velocity
u0 = 100.0
#passing velocity profile and component wise velocities
u =firedrake.interpolate(firedrake.as_vector((u0 + 100 * x /Lx, 0)),V)
#englacial temperatures
T = 254.15
#accumulation
a = -2.5

# %%
fig, axes = icepack.plot.subplots()
contours =icepack.plot.tricontourf(h,axes = axes)
colorbar =colorbar.
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">

# %%
ice_shelf = icepack.models.IceShelf()
help(ice_shelf)
# Out:
# Help on IceShelf in module icepack.models.ice_shelf object:
#
# class IceShelf(builtins.object)
#  |  IceShelf(viscosity=<function viscosity_depth_averaged at 0x11f81fa60>, side_friction=<function side_friction at 0x11f81f840>, gravity=<function gravity at 0x11f81fae8>, terminus=<function terminus at 0x11f463b70>, penalty=<function normal_flow_penalty at 0x11f81f730>)
#  |
#  |  Class for modelling the flow of floating ice shelves
#  |
#  |  This class provides functions that solve for the velocity and
#  |  thickness of a floating ice shelf. The relevant physics can be found
#  |  in ch. 6 of Greve and Blatter.
#  |
#  |  .. seealso::
#  |     :py:func:`icepack.models.viscosity.viscosity_depth_averaged`
#  |        Default implementation of the ice shelf viscous action
#  |
#  |  Methods defined here:
#  |
# ...

# %%
opts = {'dirichlet_ids':[1],'side_wall_ids':[3,4], 'tol': 10e-8,'side_wall_ids':[3,4]}
u = ice_shelf.diagnostic_solve(u0=u,h=h,A=A,**opts)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-d791a5ee878f> in <module>
#       1 opts = {'dirichlet_ids':[1],'side_wall_ids':[3,4], 'tol': 10e-8,'side_wall_ids':[3,4]}
# ----> 2 u = ice_shelf.diagnostic_solve(u0=u,h=h,A=A,**opts)
#
# NameError: name 'A' is not defined
